# %% [markdown]
# # Importing pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Series

# %% [markdown]
# Methods to create series

# %%
lst = [44846, 30906, 39593, 24200, 43044]
arr = np.array(lst)
labels = ['USA','IND','China','Japan','UK']
dct = {
    'USA':44846,
    "IND":30906,
    'China':39593,
    'Japan':24200,
    'UK':43044
}

# %%
ser = pd.Series(lst)

# %%
pd.Series(arr)
# Out:
# 0    44846
# 1    30906
# 2    39593
# 3    24200
# 4    43044
# dtype: int64

# %%
pd.Series(labels)
# Out:
# 0      USA
# 1      IND
# 2    China
# 3    Japan
# 4       UK
# dtype: object

# %%
ser = pd.Series(arr,index=labels)

# %%
ser
# Out:
# USA      44846
# IND      30906
# China    39593
# Japan    24200
# UK       43044
# dtype: int64

# %%
pd.Series(dct)
# Out:
# USA      44846
# IND      30906
# China    39593
# Japan    24200
# UK       43044
# dtype: int64

# %%
arr = np.random.randint(20000,50000,25).reshape(5,5)
arr
# Out:
# array([[48139, 23037, 22948, 27062, 21719],
#        [26251, 32147, 28616, 33464, 26582],
#        [24574, 31831, 36356, 22322, 43193],
#        [44639, 37277, 26312, 47366, 35356],
#        [28813, 23973, 35184, 43460, 41479]])

# %%
'A B C D E'.split()
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
demo_data = pd.DataFrame(arr,columns=labels,index=['A', 'B', 'C', 'D', 'E'])

# %%
demo_data
# Out:
#      USA    IND  China  Japan     UK
# A  48139  23037  22948  27062  21719
# B  26251  32147  28616  33464  26582
# C  24574  31831  36356  22322  43193
# D  44639  37277  26312  47366  35356
# E  28813  23973  35184  43460  41479

# %%
mini = demo_data[['USA','UK']]

# %%
mini
# Out:
#      USA     UK
# A  48139  21719
# B  26251  26582
# C  24574  43193
# D  44639  35356
# E  28813  41479

# %%
mini['USA'][1] = 0
# Out:
# <ipython-input-15-69564fbbb65a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini['USA'][1] = 0

# %%
demo_data
# Out:
#      USA    IND  China  Japan     UK
# A  48139  23037  22948  27062  21719
# B  26251  32147  28616  33464  26582
# C  24574  31831  36356  22322  43193
# D  44639  37277  26312  47366  35356
# E  28813  23973  35184  43460  41479

# %%
demo_data.loc['A']
# Out:
# USA      48139
# IND      23037
# China    22948
# Japan    27062
# UK       21719
# Name: A, dtype: int64

# %%
demo_data.iloc[0]
# Out:
# USA      48139
# IND      23037
# China    22948
# Japan    27062
# UK       21719
# Name: A, dtype: int64

# %%
lst
# Out:
# [44846, 30906, 39593, 24200, 43044]

# %%
demo_data['German'] = [44846, 30906, 39593, 24200, 43044]

# %%
demo_data
# Out:
#      USA    IND  China  Japan     UK  German
# A  48139  23037  22948  27062  21719   44846
# B  26251  32147  28616  33464  26582   30906
# C  24574  31831  36356  22322  43193   39593
# D  44639  37277  26312  47366  35356   24200
# E  28813  23973  35184  43460  41479   43044

# %%
demo_data.columns
# Out:
# Index(['USA', 'IND', 'China', 'Japan', 'UK', 'German'], dtype='object')

# %%
demo_data['Total'] = demo_data[['USA', 'IND', 'China', 'Japan', 'UK', 'German']].sum(axis=1)

# %%
demo_data
# Out:
#      USA    IND  China  Japan     UK  German   Total
# A  48139  23037  22948  27062  21719   44846  187751
# B  26251  32147  28616  33464  26582   30906  177966
# C  24574  31831  36356  22322  43193   39593  197869
# D  44639  37277  26312  47366  35356   24200  215150
# E  28813  23973  35184  43460  41479   43044  215953

# %%
demo_data[['USA', 'IND', 'China', 'Japan', 'UK', 'German']].loc['A'].sum()
# Out:
# 187751

# %% [markdown]
# # Reading CSV file in pandas

# %%
data = pd.read_csv('https://github.com/sukhioo7/pandas_data/blob/main/Data.csv?raw=True')

# %%
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       NaN
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7      NaN  48.0  79000.0       NaN
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
data[data['Age']>40]
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No

# %%
data.head(5)
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes

# %%
data.tail(2)
# Out:
#    Country   Age   Salary Purchased
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
data.columns
# Out:
# Index(['Country', 'Age', 'Salary', 'Purchased'], dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    10 non-null     object
#  1   Age        9 non-null      float64
#  2   Salary     9 non-null      float64
#  3   Purchased  10 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 448.0+ bytes

# %%
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
data['Country'].value_counts()
# Out:
# France     4
# Spain      3
# Germany    3
# Name: Country, dtype: int64

# %%
data['Purchased'].value_counts()
# Out:
# No     5
# Yes    5
# Name: Purchased, dtype: int64

# %%
data['Country'][1] = 'IND'
# Out:
# <ipython-input-36-5f2595751206>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Country'][1] = 'IND'

# %%
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1      IND  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
data['Salary'].mean()
# Out:
# 63777.77777777778

# %%
data['Age'].median()
# Out:
# 38.0

# %% [markdown]
# Droping null values

# %%
data.dropna(inplace=True)

# %%
data.reset_index(drop=True)
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1      IND  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4   France  35.0  58000.0       Yes
# 5   France  48.0  79000.0       Yes
# 6  Germany  50.0  83000.0        No
# 7   France  37.0  67000.0       Yes

# %%
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1      IND  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 5   France  35.0  58000.0       Yes
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
m = data['Salary'].median()
m
# Out:
# 64000.0

# %%
data['Salary']
# Out:
# 0    72000.0
# 1    48000.0
# 2    54000.0
# 3    61000.0
# 5    58000.0
# 7    79000.0
# 8    83000.0
# 9    67000.0
# Name: Salary, dtype: float64

# %%
data['Salary']  = data['Salary'].fillna(value=m)

# %%
data['Age'].fillna(value=data['Age'].median())
# Out:
# 0    44.0
# 1    27.0
# 2    30.0
# 3    38.0
# 5    35.0
# 7    48.0
# 8    50.0
# 9    37.0
# Name: Age, dtype: float64

# %% [markdown]
# Fill null values

# %%
data['Age'].astype('int')
# Out:
# 0    44
# 1    27
# 2    30
# 3    38
# 5    35
# 7    48
# 8    50
# 9    37
# Name: Age, dtype: int64

# %%
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       NaN
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6      NaN   NaN  52000.0        No
# 7   France  48.0  79000.0       NaN
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
data.isnull().sum()
# Out:
# Country      0
# Age          0
# Salary       0
# Purchased    0
# dtype: int64

# %%
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       NaN
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6      NaN   NaN  52000.0        No
# 7   France  48.0  79000.0       NaN
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
data.mode()
# Out:
#   Country   Age   Salary Purchased
# 0  France  27.0  48000.0        No
# 1     NaN  30.0  52000.0       NaN
# 2     NaN  35.0  54000.0       NaN
# 3     NaN  37.0  58000.0       NaN
# 4     NaN  38.0  61000.0       NaN
# 5     NaN  40.0  67000.0       NaN
# 6     NaN  44.0  72000.0       NaN
# 7     NaN  48.0  79000.0       NaN
# 8     NaN  50.0  83000.0       NaN

# %%
data.fillna(value=data.median(),inplace=True)
# Out:
# <ipython-input-77-714a4204ecce>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.fillna(value=data.median(),inplace=True)

# %%
data['Country'].mode()[0]
# Out:
# 'France'

# %%
data['Country'].fillna(value=data['Country'].mode()[0],inplace=True)

# %%
data['Purchased'].fillna(value=data['Purchased'].mode()[0],inplace=True)

# %%
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0        No
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  61000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6   France  38.0  52000.0        No
# 7   France  48.0  79000.0        No
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
grouped_data = data.groupby(by='Country')

# %%
grouped_data.max()
# Out:
#           Age   Salary Purchased
# Country
# France   48.0  79000.0       Yes
# Germany  50.0  83000.0       Yes
# Spain    38.0  61000.0        No

# %%
data.describe(include='all').T
# Out:
#           count unique     top freq     mean           std      min      25%  \
# Country      10      3  France    5      NaN           NaN      NaN      NaN
# Age        10.0    NaN     NaN  NaN     38.7      7.257946     27.0     35.5
# Salary     10.0    NaN     NaN  NaN  63500.0  11597.413505  48000.0  55000.0
# Purchased    10      2      No    7      NaN           NaN      NaN      NaN
#
#                50%      75%      max
# Country        NaN      NaN      NaN
# Age           38.0     43.0     50.0
# Salary     61000.0  70750.0  83000.0
# Purchased      NaN      NaN      NaN

# %%
data['Country'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
data['Country'].nunique()
# Out:
# 3

# %%
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0        No
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  61000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6   France  38.0  52000.0        No
# 7   France  48.0  79000.0        No
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
data1 = data.loc[:4]
data2 = data.loc[5:]

# %%
data1
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0        No
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  61000.0       Yes

# %%
data2
# Out:
#    Country   Age   Salary Purchased
# 5   France  35.0  58000.0       Yes
# 6   France  38.0  52000.0        No
# 7   France  48.0  79000.0        No
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
pd.concat([data1,data2],axis=0)
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0        No
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  61000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6   France  38.0  52000.0        No
# 7   France  48.0  79000.0        No
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
pd.concat([data1,data2],axis=1)
# Out:
#    Country   Age   Salary Purchased  Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No      NaN   NaN      NaN       NaN
# 1    Spain  27.0  48000.0        No      NaN   NaN      NaN       NaN
# 2  Germany  30.0  54000.0        No      NaN   NaN      NaN       NaN
# 3    Spain  38.0  61000.0        No      NaN   NaN      NaN       NaN
# 4  Germany  40.0  61000.0       Yes      NaN   NaN      NaN       NaN
# 5      NaN   NaN      NaN       NaN   France  35.0  58000.0       Yes
# 6      NaN   NaN      NaN       NaN   France  38.0  52000.0        No
# 7      NaN   NaN      NaN       NaN   France  48.0  79000.0        No
# 8      NaN   NaN      NaN       NaN  Germany  50.0  83000.0        No
# 9      NaN   NaN      NaN       NaN   France  37.0  67000.0       Yes
